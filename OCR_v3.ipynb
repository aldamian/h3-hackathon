# %% [markdown]
# <a href="https://colab.research.google.com/github/aldamian/H3-Hackathon/blob/main/OCR_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Setup

# %%
# !sudo apt install tesseract-ocr
# !sudo apt install tesseract-ocr-ron - tesseract-ocr 
# !sudo apt install poppler-utils
# !pip install pytesseract
# !pip install pdf2image
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# tesseract-ocr-ron is already the newest version (4.00~git24-0e00fe6-1.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# poppler-utils is already the newest version (0.62.0-2ubuntu2.12).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.7/dist-packages (0.3.9)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.7/dist-packages (from pytesseract) (9.1.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from pytesseract) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->pytesseract) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.7/dist-packages (1.16.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from pdf2image) (9.1.1)

# %%
import shutil
import os
import random
import pytesseract
from PIL import Image, ImageDraw
import cv2
import numpy as np
from matplotlib import pyplot as plt
from pdf2image import convert_from_path
from google.colab.patches import cv2_imshow
from google.colab import drive

# %%
# drive._mount("/content/gdrive")
# %cd /content/drive/MyDrive/Colab Notebooks/Data
# Out:
# /content/drive/MyDrive/Colab Notebooks/Data

# %% [markdown]
# # Document
#
# Externare.pdf

# %%
images = convert_from_path("Externare.pdf")
fp = images[0]
sp = images[1]

# %%
print(images)
print(fp.size)
# Out:
# [<PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200 at 0x7FDAA20289D0>, <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200 at 0x7FDAA2028550>]
# (1700, 2200)

# %%
def pil_to_cv(pil_image):
  cv_image = np.array(pil_image)
  # Convert RGB to BGR 
  return cv_image[:, :, ::-1].copy()

# %%
fp = pil_to_cv(fp)
sp = pil_to_cv(sp)

# %%
# cv2_imshow(fp)

# %%
cv2.imwrite("/tmp/fp.png", fp)
# Out:
# True

# %%
cv2.imwrite("/tmp/sp.png", sp)
# Out:
# True

# %%
# Need correct data format
fp = cv2.imread("/tmp/fp.png")
sp = cv2.imread("/tmp/sp.png")

# %%
#https://stackoverflow.com/questions/28816046/
#displaying-different-images-with-actual-size-in-matplotlib-subplot
def display(im_path):
  dpi = 80
  im_data = plt.imread(im_path)
  height, width, depth = im_data.shape

  # What size does the figure need to be in inches to fit the image?
  figsize = width / float(dpi), height / float(dpi)

  # Create a figure of the right size with the axes that takes up the full figure
  fig = plt.figure(figsize=figsize)
  ax = fig.add_axes([0, 0, 1, 1])

  # Hide spines, ticks, etc. 
  ax.axis('off')

  # Display the image
  ax.imshow(im_data, cmap='gray')

  plt.show()

# %%
display("/tmp/fp.png")

# %% [markdown]
# # Pre-processing - Rotation / Deskewing
#
# Much of the methods were unnecessary.
# The only useful one for this particular scenario is Rotation in case the user's picture is not straight.

# %%
#https://becominghuman.ai/how-to-automatically-deskew-straighten-a-text-image-using-opencv-a0c30aed83df
import numpy as np

def getSkewAngle(cvImage) -> float:
    # Prep image, copy, convert to gray scale, blur, and threshold
    newImage = cvImage.copy()
    gray = cv2.cvtColor(newImage, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (9, 9), 0)
    thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

    # Apply dilate to merge text into meaningful lines/paragraphs.
    # Use larger kernel on X axis to merge characters into single line, cancelling out any spaces.
    # But use smaller kernel on Y axis to separate between different blocks of text
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (30, 5))
    dilate = cv2.dilate(thresh, kernel, iterations=2)

    # Find all contours
    contours, hierarchy = cv2.findContours(dilate, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    contours = sorted(contours, key = cv2.contourArea, reverse = True)
    for c in contours:
        rect = cv2.boundingRect(c)
        x,y,w,h = rect
        cv2.rectangle(newImage,(x,y),(x+w,y+h),(0,255,0),2)

    # Find largest contour and surround in min area box
    largestContour = contours[0]
    print (len(contours))
    minAreaRect = cv2.minAreaRect(largestContour)
    cv2.imwrite("temp/boxes.jpg", newImage)
    # Determine the angle. Convert it to the value that was originally used to obtain skewed image
    angle = minAreaRect[-1]
    if angle < -45:
        angle = 90 + angle
    return -1.0 * angle
# Rotate the image around its center
def rotateImage(cvImage, angle: float):
    newImage = cvImage.copy()
    (h, w) = newImage.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    newImage = cv2.warpAffine(newImage, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return newImage

# %%
# Deskew image
def deskew(cvImage):
    angle = getSkewAngle(cvImage)
    return rotateImage(cvImage, -1.0 * angle)

# %% [markdown]
# # OCR with PyTesseract

# %%
fp_text = pytesseract.image_to_string(fp)
# print(fp_text)

# %%
sp_text = pytesseract.image_to_string(sp)

# %%
text = fp_text + sp_text
text = text.replace('$', 'S')
# print(text)

# %% [markdown]
# # Rules Based NER

# %%
text = text.split("\n\n")
text.remove(' ')
text.pop()
text.pop(0)
# Out:
# 'ps |\nCapitalel = ASSM®'

# %%
new_text = []
for segment in text:
  segment = segment.strip()
  segment = segment.lower()
  # keep percentages, points, slash, star
  punc = '''!()[]{};'",<>?@#$^&_~"”»'''
  for ele in segment:
      if ele in punc:
          segment = segment.replace(ele, "")

  new_text.append(segment)
  print(segment)
# Out:
# spitalul clinic de boli infectioase si tropicale
# dr.victor babes
#
# boli infectioase adulti sectia 1 grupa sangvina: rh:
# telefon: alergic la:
# bilet de externare
# nr. foaie internare: 888888 nume si prenume: ionescu andrei
# judet/sector: suceava cnp: 1710922076635
# localitate: suceava varsta / sex: 50 ani / masculin
# adresa: alee ghiroda19 telefon: 0723 978 658
# data internarii: 13.01.2022 18:45 data externarii: 28.01.2022 11:40
#
# diagnostic externare:
# pneumonie interstitiala acuta bilaterala
# infectie sars cov2 confirmata
# infectie acuta de cai respiratorii superioare
# hipertensiune arteriala
# epicriza:
# pacient de sex masculin in varsta de 50 de ani cunoscut cu hipertensiune arteriala in tratament se prezinta pentru febra 384 grade celsius mialgii
# si cefalee usoara simptomatologie debutata in cursul zilei de azi. pe data de 29.01.2022 a efectuat test ag rapid cu rezultat pozitiv motiv pentru care
# este adus de ambulanta pentru evaluare clinico-biologica si se decide internarea.
# ahc: frate - diabet
# app: hta aritmii cardiace le descrie ca palpitatii in tratament hernie operata in urma cu 30 de ani
# medicatie personala : metoprolol panangin
# examen clinic la internare: stare generala medie subfebril 375 grade constient normoponderal h=176 cm g= 70kg tegumente cu eruptii
# maculare difuz distribuite la nivelul trunchiului si cateva la nivelul antebratelor nepruriginoase afirmativ pacientul relateaza ca apar o data pe luna
# limba saburala fanere trofice tesut conjunctiv-adipos bine reprezentat sistem muscular normoton normotrof normokinetic sistem osteo-articular
# aparent integru morfo-functional murmur vezicular prezent bilateral inasprit fara raluri bronsice supraadaugate spo2=97% in aa zgomote cardiace
# echidistante echipotente aparent fara sufluri sau zgomote supraadaugate ta=130/90 mm hg av=100 bpm fara edeme gambiere fara jugulare
# turgescente abdomen mobil cu miscarile respiratorii nedureros spontan sau la palpare fara semne de iritatie peritoneala tranzit intestinal prezent
# scaun cu aspect normal afirmativ ficat la 15cm sub rebordul splina nepalpabia manevra giordano negativa bilateral diureza prezenta cu mictiuni
# fiziologice afirmativ fara redoare de ceafa fara semne neurologice de focar.
# s-a efectuat ekg cu ritm sinusal fara modificari acute de faza terminala
# biologic la internare: sindrom inflamator usor in contectul infectiei cu sars-cov2 proteina c reactiva=* 0.89 mg/dl si limfopenie
#  limfocite=* 400 /yl  limfocite%=* 4.9 %
# radiologic la internare: torace rotat. mici infiltrate interstitiale distribuite in 1/3 inferioare ale ambelor campuri pulmonare drstg. scd laterale
# libere. cord cu aspect rg in limite normale.
# coroborand datele clinice si paraclinice s-au stabilit diagnosticele de mai sus.
# pe parcursul internarii a primit tratament antiviral cu remdesivir timp de 5 zile tratament anticoagulant cu clexane in doza profilactica perfuzii de
# reechilibrare hidro-electrolitica tratament simptomatic si protectie gastrica. pacientul a continuat medicatia personala pentru afectiunile cronice
# preexistente.
# evolutia clinica a fost favorabila cu ameliorarea simptomatologiei prezente la internare in contextul infectiei sars cov-2. se externeaza cu stare
# generala ameliorata afebril echilibrat cardio-respirator si digestiv ots fara sim fara semne neurologice de focar.
# analize de laborator:
# 29.01.22 19:21:
# alaninaminotransferaza=38 u/l clor=100 mmol/l  glucoza=98 mg/dl  potasiu=4.4 mmol/l  sodiu=137 mmol/l  creatinina=1.1
# mg/dl  proteina c reactiva=* 0.89 mg/dl  aspartataminotransferaza=21 u/l  lactat dehidrogenaza*=181 u/l  feritina*=219.5 ng/ml
# fibrinogen=374 mg/dl  activitatea de protrombina=106 % inr=0.96 inr timp quick=12.8 sec aptt -timp partial de
# tromboplastina=31.2 sec d-dimer*=0.25 pg/ml  bazofile=0/l  bazofile%=0.4%   eozinofile=0/pl — eozinofile%=0.4%
# neutrofile%=* 83.3%  neutrofile=* 7200 /pl  hematocrit=44.7%  hemoglobina=15.4 g/dl  limfocite=* 400 /l  limfocite%=*
# 49% mch=*33.8pg mchc=34.4 g/dl mcv=98.3fl   monocite=1000/l  monocite%=* 11.0%  volum mediu
# plachetar=10.1fl —  trombocite=193000 /pl  eritrocite=4.55 *1046/pl = rdw=12.9%  numar total de leucocite=8700 /l
# recomandari:
# 1. se recomanda igiena personala riguroasa spalare frecventa pe maini se va evita atingerea fetei fara dezinfectarea prealabila
# mainilor.
# 2. pacienta se poate intoarce in colectivitate si la finalul perioadei de izolare conform recomandarilor autoritatilor competente fara a
# necesara retestare si poate desfasura activitatile curente si profesionale cu pastrarea distantarii sociale si purtarea mastii de protectie.
# 3. va respecta recomandarile privind distantarea fizica fata de alte persoane.
# 4. se recomanda purtarea mastii de protectie pe perioada parasirii domiciliului dupa incheierea perioadei de izolare.
# 5. hidratare adecvata minim 2l/ zi. regim alimentar echilibrat
# 6. va informa medicul de familie despre spitalizarea actuala care 0 va urmari pe perioada izolarii la domiciliu si a convalescentei iar
# caz de agravare a starii de sanatate va solicita ambulanta 112.
# 7. va efectua in ambulator prin cabinetul medicului de familie peste aproximativ 10 zile urmatoarele analize de sang
# hemoleucograma crp fibrinogen d-dimeri tgp creatinina glicemie ldh na k cl in clinica noastra se pot efectua cu bilet d
# trimitere de la medicul de familie pentru consult boli infectioase.
# 8. va efectua in ambulator consult de specialitate pneumologie.
# 9. vaccinare conform protocolului national cu unul dintre vaccinurile aprobate la nivel national
# 10. monitorizare periodica prin cabinetul medicului de familie.
# 11. continua tratamentul pentru afectiunile cronice cu monitorizare periodica prin cabinetul medicilor de specialitate
# sef sectie: medic curant:
# dr pop ioan
# medic primar boli infectioase
# dr. georgescu maria
# medic specialist boli infectioase
# sos. mihai bravu nr. 281 sector 3 bucuresti
# cui: 4266049
# telefon: 021/317.27.27 021/317.27.28
#
#
# fax: 021/317.27.2 unitate afiata in -
# e-mail: officespitalulbabes ro proces de acreditare ek

# %%
def date_split(text):
  if text.count("data") == 1:
    return text.split("data")[0]
  return "data".join(text.split("data", 2)[:2])

# %%
hospital = new_text[0]
department = new_text[2].split('grupa')[0]

dates = new_text[4].splitlines()[-1]
admission_date = date_split(dates)
discharge_date = dates.replace(admission_date, '')

discharge_diagnostic = new_text[6].split(':')[1]
epicrisis = new_text[7].split(':', 1)[1].capitalize()
inpatient_clinical_exam = new_text[8].split(':', 1)[1].lstrip() + '\n\n' + new_text[9].capitalize()
inpatient_biological_exam = new_text[10].strip() + '\n' + new_text[11].lstrip()
inpatient_radiology = new_text[12].split(':', 1)[1].lstrip().capitalize()
treatment = new_text[13].split('.', 1)[1].capitalize()

# %%
"""
class DischargeTicket:
  def __init__(self, _hospital, _department, _admission_date, _discharge, )
"""

# %% [markdown]
# # Long term - goal: general approach
#
# Discharge receipts very to a considerable degree, so a rules based approach is naive at best.
#
# Solutions:
#
# 1. Use ML for NER  - spaCy's NER
# 2. Generate custom word vectors in Gensim because spaCy's models are trained on news and media, and as a result they perform poor in specialized domains such as law or healthcare
# 3. Traing spaCy's NER on domain specific texts: (eg. 50,000 discharge receipts)
# 4. Look into syntetic data
#
# Note: Used spaCy's large romanian language model in another notebook but the results were very poor.

# %% [markdown]
# # Experiment - Translate text to EN to perform NLP and back to RO for display
#
# Tried to use deepL translation API but it doesn't yet support romanian.
# Google translate is accurate but there's a 5000 word limit.

# %%
# !pip install deep_translator

# %%
"""
from deep_translator import GoogleTranslator

fp_en = GoogleTranslator(source='ro', target='en').translate(fp_text)
fp_ro = GoogleTranslator(source='en', target='ro').translate(fp_en)
"""
